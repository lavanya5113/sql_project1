# %%
import matplotlib.pyplot as plt

# %%
import pandas as pd

# %%
df_linechart=pd.read_csv(r"C:\Users\Lavanya N\Downloads\spotify project\popularity over years.csv")

# %%
plt.figure(figsize=(5,2))
plt.scatter(df_linechart['avg(popularity)'],df_linechart['released_year'])
plt.title('popularity over years')
plt.xlabel('average popularity')
plt.ylabel('years')
plt.show()

# %%
df_barchart=pd.read_csv(r"C:\Users\Lavanya N\Downloads\spotify project\danceability vs popularity.csv")

# %%
plt.figure(figsize=(5,2))
plt.bar(df_barchart['danceability_level'],df_barchart['average_popularity'])
plt.title('Danceability vs Popularity')
plt.xlabel('Danceability level')
plt.ylabel('Average Popularity')
plt.show()

# %%
df_energychart=pd.read_csv(r"C:\Users\Lavanya N\Downloads\spotify project\energy vs popularity.csv")

# %%
plt.figure(figsize=(5,2))
plt.bar(df_energychart['energy_level'],df_energychart['popularity_average'])
plt.xlabel('energy level')
plt.ylabel('Average popularity')
plt.title('Danceability vs Popularity')
plt.show()

# %%
df_timechart=pd.read_csv(r"C:\Users\Lavanya N\Downloads\spotify project\time vs popularity.csv")

# %%
plt.figure(figsize=(5,2))
plt.bar(df_timechart['duration_level'],df_timechart['popularity_average'])
plt.xlabel('Duration level of songs')
plt.ylabel('Average popularity')
plt.title('Duration level of songs vs Popularity')
plt.show()

# %%
df_artistchart=pd.read_csv(r"C:\Users\Lavanya N\Downloads\spotify project\top 10 artists.csv")

# %%
plt.figure(figsize=(34,10))
plt.plot(df_artistchart['artist_name'],df_artistchart['avg(popularity)'])
plt.xlabel('artist name')
plt.ylabel('Average popularity')
plt.title('Top 10 artist')
plt.show()

# %%
df_moodchart=pd.read_csv(r"C:\Users\Lavanya N\Downloads\spotify project\mood vs popularity.csv")

# %%
plt.figure(figsize=(5,2))
plt.bar(df_moodchart['mood_level'],df_moodchart['popularity_average'])
plt.xlabel('Mood level')
plt.ylabel('average popularity')
plt.title('Mood level vs popularity')
plt.show()
